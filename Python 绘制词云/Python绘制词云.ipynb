# %% [markdown]
# # Python绘制词云（jieba+wordcloud+matplotlib）

# %%
#pip install jieba
#pip install wordcloud
#pip install matplotlib

# %%
import jieba
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.rcParams['savefig.dpi'] = 600 #图片像素
plt.rcParams['figure.dpi'] = 600 #分辨率

# %%
#导入一个文本文件
text = open('唐诗三百首.txt',encoding='utf8')
mylist = list(text)

# %%
#对mylist进行遍历,并将其做分词切割后做成列表
word_list = [''.join(jieba.cut(sentence)) for sentence in mylist]

#将word_list内的元素用空格连接起来，以便于计算词频
new_text = ''.join(word_list)

#设置词云的字体和背景颜色
wordcloud = WordCloud(font_path='/Library/Fonts/Songti.ttc',background_color='black').generate(new_text)
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache /var/folders/cy/myb1cljs29jbkm5wp8v0lr6m0000gn/T/jieba.cache
# Loading model cost 0.772 seconds.
# Prefix dict has been built successfully.

# %%
#设置词云的字体和背景颜色
wordcloud = WordCloud(font_path='/Library/Fonts/Songti.ttc',background_color='black').generate(new_text)
plt.figure(figsize=(15,9)) 
plt.imshow(wordcloud)
plt.axis('off')
plt.show()
